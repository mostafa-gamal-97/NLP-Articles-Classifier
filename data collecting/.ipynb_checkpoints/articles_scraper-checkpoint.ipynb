# %% [markdown]
# ## Getting Started

# %% [markdown]
# Links of pages used for data scraping:
#
# [english ahram business / economy](https://english.ahram.org.eg/AllCategory/3/12/Business/Economy/0.aspx)
#
# [english ahram sports / world](https://english.ahram.org.eg/AllCategory/6/55/Sports/World/0.aspx)
#
# [english ahram arts&culture / visualart](https://english.ahram.org.eg/AllCategory/5/25/Arts%20&%20Culture/Visual%20Art/0.aspx)
#
# [english ahram arts&culture / film](https://english.ahram.org.eg/AllCategory/5/32/Arts%20&%20Culture/Film/0.aspx)
#
# [english ahram arts&culture / music](https://english.ahram.org.eg/AllCategory/5/33/Arts%20&%20Culture/Music/0.aspx)
#
# [english ahram arts&culture / stage&street](https://english.ahram.org.eg/AllCategory/5/35/Arts%20&%20Culture/Stage%20&%20Street/0.aspx)
#
# * these links redirect to the first page in economy, visualart, and world sports.
#
# * Each page contains 20 articles (will show in Logic Testing).
#
# * we can use a for loop to access different pages and scrape articles titles from them.
#
# ___
# One thing you will notice is that **elahram site** indexes pages in multiples of 20 starting from 0.
#
# **meaning**, page1: 0, page2: 20, page3: 40, page4:60, and so on.
#
# You can check by switching from page 1 to 2 to 3 and look the at the number at end of url.

# %%
# 1st step : import required libraries
import requests
from bs4 import BeautifulSoup
import pandas as pd
# Increase width to see the article_title clearly
pd.set_option('max_colwidth', None)

# %% [markdown]
# ### Logic Testing

# %%
# 2nd step: use requests to fetch the url
response = requests.get("https://english.ahram.org.eg/AllCategory/3/12/Business/Economy/0.aspx")
# 3rd step: save page content/markup
src = response.content
# 4th step: create a beautifulsoup object to parse content
soup = BeautifulSoup(src, 'lxml')

# %%
#print(src)
#print()
#print(soup)

# %%
# 5th step: find the elements containing info we need --> article title
article_title = []
articles_titles = soup.find_all("div", {"class":"col-md-12 col-lg-12 mar-top-outer"})

for i in range(len(articles_titles)):
    article_title.append(articles_titles[i].text)

print(article_title[2])
print(f"Number of articles per page = {len(article_title)}")
# Out:
# Egypt plans to issue Chinese Yuan-dominated bonds: Finance minister
#
#
#
# Minister of Finance Mohamed Maait announced on Wednesday that the government is considering issuing Yuan-dominated bonds that will target the Chinese market, which is the second largest bond market globally.
#
#
#
#
# Number of articles per page = 20

# %% [markdown]
# ## Economy

# %%
# %%time
title_economy = []
for i in range(0, 10000, 20):
    response = requests.get("https://english.ahram.org.eg/AllCategory/3/12/Business/Economy/"+str(i)+".aspx")
    src = response.content
    soup = BeautifulSoup(src, 'lxml')
    articles_titles = soup.find_all("div", {"class":"col-md-12 col-lg-12 mar-top-outer"})
    # append articles in each page to article_title
    for j in range(len(articles_titles)):
        title_economy.append(articles_titles[j].text)
    print(f"iteration {int(i/20)} is done")
print("DONE !")
# Out:
# iteration 0 is done
# iteration 1 is done
# iteration 2 is done
# iteration 3 is done
# iteration 4 is done
# iteration 5 is done
# iteration 6 is done
# iteration 7 is done
# iteration 8 is done
# iteration 9 is done
# iteration 10 is done
# iteration 11 is done
# iteration 12 is done
# iteration 13 is done
# iteration 14 is done
# iteration 15 is done
# iteration 16 is done
# iteration 17 is done
# iteration 18 is done
# iteration 19 is done
# iteration 20 is done
# iteration 21 is done
# iteration 22 is done
# iteration 23 is done
# iteration 24 is done
# iteration 25 is done
# iteration 26 is done
# iteration 27 is done
# iteration 28 is done
# iteration 29 is done
# iteration 30 is done
# iteration 31 is done
# iteration 32 is done
# iteration 33 is done
# iteration 34 is done
# iteration 35 is done
# iteration 36 is done
# iteration 37 is done
# iteration 38 is done
# iteration 39 is done
# iteration 40 is done
# iteration 41 is done
# iteration 42 is done
# iteration 43 is done
# iteration 44 is done
# iteration 45 is done
# iteration 46 is done
# iteration 47 is done
# iteration 48 is done
# iteration 49 is done
# iteration 50 is done
# iteration 51 is done
# iteration 52 is done
# iteration 53 is done
# iteration 54 is done
# iteration 55 is done
# iteration 56 is done
# iteration 57 is done
# iteration 58 is done
# iteration 59 is done
# iteration 60 is done
# iteration 61 is done
# iteration 62 is done
# iteration 63 is done
# iteration 64 is done
# iteration 65 is done
# iteration 66 is done
# iteration 67 is done
# iteration 68 is done
# iteration 69 is done
# iteration 70 is done
# iteration 71 is done
# iteration 72 is done
# iteration 73 is done
# iteration 74 is done
# iteration 75 is done
# iteration 76 is done
# iteration 77 is done
# iteration 78 is done
# iteration 79 is done
# iteration 80 is done
# iteration 81 is done
# iteration 82 is done
# iteration 83 is done
# iteration 84 is done
# iteration 85 is done
# iteration 86 is done
# iteration 87 is done
# iteration 88 is done
# iteration 89 is done
# iteration 90 is done
# iteration 91 is done
# iteration 92 is done
# iteration 93 is done
# iteration 94 is done
# iteration 95 is done
# iteration 96 is done
# iteration 97 is done
# iteration 98 is done
# iteration 99 is done
# iteration 100 is done
# iteration 101 is done
# iteration 102 is done
# iteration 103 is done
# iteration 104 is done
# iteration 105 is done
# iteration 106 is done
# iteration 107 is done
# iteration 108 is done
# iteration 109 is done
# iteration 110 is done
# iteration 111 is done
# iteration 112 is done
# iteration 113 is done
# iteration 114 is done
# iteration 115 is done
# iteration 116 is done
# iteration 117 is done
# iteration 118 is done
# iteration 119 is done
# iteration 120 is done
# iteration 121 is done
# iteration 122 is done
# iteration 123 is done
# iteration 124 is done
# iteration 125 is done
# iteration 126 is done
# iteration 127 is done
# iteration 128 is done
# iteration 129 is done
# iteration 130 is done
# iteration 131 is done
# iteration 132 is done
# iteration 133 is done
# iteration 134 is done
# iteration 135 is done
# iteration 136 is done
# iteration 137 is done
# iteration 138 is done
# iteration 139 is done
# iteration 140 is done
# iteration 141 is done
# iteration 142 is done
# iteration 143 is done
# iteration 144 is done
# iteration 145 is done
# iteration 146 is done
# iteration 147 is done
# iteration 148 is done
# iteration 149 is done
# iteration 150 is done
# iteration 151 is done
# iteration 152 is done
# iteration 153 is done
# iteration 154 is done
# iteration 155 is done
# iteration 156 is done
# iteration 157 is done
# iteration 158 is done
# iteration 159 is done
# iteration 160 is done
# iteration 161 is done
# iteration 162 is done
# iteration 163 is done
# iteration 164 is done
# iteration 165 is done
# iteration 166 is done
# iteration 167 is done
# iteration 168 is done
# iteration 169 is done
# iteration 170 is done
# iteration 171 is done
# iteration 172 is done
# iteration 173 is done
# iteration 174 is done
# iteration 175 is done
# iteration 176 is done
# iteration 177 is done
# iteration 178 is done
# iteration 179 is done
# iteration 180 is done
# iteration 181 is done
# iteration 182 is done
# iteration 183 is done
# iteration 184 is done
# iteration 185 is done
# iteration 186 is done
# iteration 187 is done
# iteration 188 is done
# iteration 189 is done
# iteration 190 is done
# iteration 191 is done
# iteration 192 is done
# iteration 193 is done
# iteration 194 is done
# iteration 195 is done
# iteration 196 is done
# iteration 197 is done
# iteration 198 is done
# iteration 199 is done
# iteration 200 is done
# iteration 201 is done
# iteration 202 is done
# iteration 203 is done
# iteration 204 is done
# iteration 205 is done
# iteration 206 is done
# iteration 207 is done
# iteration 208 is done
# iteration 209 is done
# iteration 210 is done
# iteration 211 is done
# iteration 212 is done
# iteration 213 is done
# iteration 214 is done
# iteration 215 is done
# iteration 216 is done
# iteration 217 is done
# iteration 218 is done
# iteration 219 is done
# iteration 220 is done
# iteration 221 is done
# iteration 222 is done
# iteration 223 is done
# iteration 224 is done
# iteration 225 is done
# iteration 226 is done
# iteration 227 is done
# iteration 228 is done
# iteration 229 is done
# iteration 230 is done
# iteration 231 is done
# iteration 232 is done
# iteration 233 is done
# iteration 234 is done
# iteration 235 is done
# iteration 236 is done
# iteration 237 is done
# iteration 238 is done
# iteration 239 is done
# iteration 240 is done
# iteration 241 is done
# iteration 242 is done
# iteration 243 is done
# iteration 244 is done
# iteration 245 is done
# iteration 246 is done
# iteration 247 is done
# iteration 248 is done
# iteration 249 is done
# iteration 250 is done
# iteration 251 is done
# iteration 252 is done
# iteration 253 is done
# iteration 254 is done
# iteration 255 is done
# iteration 256 is done
# iteration 257 is done
# iteration 258 is done
# iteration 259 is done
# iteration 260 is done
# iteration 261 is done
# iteration 262 is done
# iteration 263 is done
# iteration 264 is done
# iteration 265 is done
# iteration 266 is done
# iteration 267 is done
# iteration 268 is done
# iteration 269 is done
# iteration 270 is done
# iteration 271 is done
# iteration 272 is done
# iteration 273 is done
# iteration 274 is done
# iteration 275 is done
# iteration 276 is done
# iteration 277 is done
# iteration 278 is done
# iteration 279 is done
# iteration 280 is done
# iteration 281 is done
# iteration 282 is done
# iteration 283 is done
# iteration 284 is done
# iteration 285 is done
# iteration 286 is done
# iteration 287 is done
# iteration 288 is done
# iteration 289 is done
# iteration 290 is done
# iteration 291 is done
# iteration 292 is done
# iteration 293 is done
# iteration 294 is done
# iteration 295 is done
# iteration 296 is done
# iteration 297 is done
# iteration 298 is done
# iteration 299 is done
# iteration 300 is done
# iteration 301 is done
# iteration 302 is done
# iteration 303 is done
# iteration 304 is done
# iteration 305 is done
# iteration 306 is done
# iteration 307 is done
# iteration 308 is done
# iteration 309 is done
# iteration 310 is done
# iteration 311 is done
# iteration 312 is done
# iteration 313 is done
# iteration 314 is done
# iteration 315 is done
# iteration 316 is done
# iteration 317 is done
# iteration 318 is done
# iteration 319 is done
# iteration 320 is done
# iteration 321 is done
# iteration 322 is done
# iteration 323 is done
# iteration 324 is done
# iteration 325 is done
# iteration 326 is done
# iteration 327 is done
# iteration 328 is done
# iteration 329 is done
# iteration 330 is done
# iteration 331 is done
# iteration 332 is done
# iteration 333 is done
# iteration 334 is done
# iteration 335 is done
# iteration 336 is done
# iteration 337 is done
# iteration 338 is done
# iteration 339 is done
# iteration 340 is done
# iteration 341 is done
# iteration 342 is done
# iteration 343 is done
# iteration 344 is done
# iteration 345 is done
# iteration 346 is done
# iteration 347 is done
# iteration 348 is done
# iteration 349 is done
# iteration 350 is done
# iteration 351 is done
# iteration 352 is done
# iteration 353 is done
# iteration 354 is done
# iteration 355 is done
# iteration 356 is done
# iteration 357 is done
# iteration 358 is done
# iteration 359 is done
# iteration 360 is done
# iteration 361 is done
# iteration 362 is done
# iteration 363 is done
# iteration 364 is done
# iteration 365 is done
# iteration 366 is done
# iteration 367 is done
# iteration 368 is done
# iteration 369 is done
# iteration 370 is done
# iteration 371 is done
# iteration 372 is done
# iteration 373 is done
# iteration 374 is done
# iteration 375 is done
# iteration 376 is done
# iteration 377 is done
# iteration 378 is done
# iteration 379 is done
# iteration 380 is done
# iteration 381 is done
# iteration 382 is done
# iteration 383 is done
# iteration 384 is done
# iteration 385 is done
# iteration 386 is done
# iteration 387 is done
# iteration 388 is done
# iteration 389 is done
# iteration 390 is done
# iteration 391 is done
# iteration 392 is done
# iteration 393 is done
# iteration 394 is done
# iteration 395 is done
# iteration 396 is done
# iteration 397 is done
# iteration 398 is done
# iteration 399 is done
# iteration 400 is done
# iteration 401 is done
# iteration 402 is done
# iteration 403 is done
# iteration 404 is done
# iteration 405 is done
# iteration 406 is done
# iteration 407 is done
# iteration 408 is done
# iteration 409 is done
# iteration 410 is done
# iteration 411 is done
# iteration 412 is done
# iteration 413 is done
# iteration 414 is done
# iteration 415 is done
# iteration 416 is done
# iteration 417 is done
# iteration 418 is done
# iteration 419 is done
# iteration 420 is done
# iteration 421 is done
# iteration 422 is done
# iteration 423 is done
# iteration 424 is done
# iteration 425 is done
# iteration 426 is done
# iteration 427 is done
# iteration 428 is done
# iteration 429 is done
# iteration 430 is done
# iteration 431 is done
# iteration 432 is done
# iteration 433 is done
# iteration 434 is done
# iteration 435 is done
# iteration 436 is done
# iteration 437 is done
# iteration 438 is done
# iteration 439 is done
# iteration 440 is done
# iteration 441 is done
# iteration 442 is done
# iteration 443 is done
# iteration 444 is done
# iteration 445 is done
# iteration 446 is done
# iteration 447 is done
# iteration 448 is done
# iteration 449 is done
# iteration 450 is done
# iteration 451 is done
# iteration 452 is done
# iteration 453 is done
# iteration 454 is done
# iteration 455 is done
# iteration 456 is done
# iteration 457 is done
# iteration 458 is done
# iteration 459 is done
# iteration 460 is done
# iteration 461 is done
# iteration 462 is done
# iteration 463 is done
# iteration 464 is done
# iteration 465 is done
# iteration 466 is done
# iteration 467 is done
# iteration 468 is done
# iteration 469 is done
# iteration 470 is done
# iteration 471 is done
# iteration 472 is done
# iteration 473 is done
# iteration 474 is done
# iteration 475 is done
# iteration 476 is done
# iteration 477 is done
# iteration 478 is done
# iteration 479 is done
# iteration 480 is done
# iteration 481 is done
# iteration 482 is done
# iteration 483 is done
# iteration 484 is done
# iteration 485 is done
# iteration 486 is done
# iteration 487 is done
# iteration 488 is done
# iteration 489 is done
# iteration 490 is done
# iteration 491 is done
# iteration 492 is done
# iteration 493 is done
# iteration 494 is done
# iteration 495 is done
# iteration 496 is done
# iteration 497 is done
# iteration 498 is done
# iteration 499 is done
# DONE !
# CPU times: total: 21.5 s
# Wall time: 15min 54s

# %%
# testing
print(title_economy[3])
# Out:
# Gold prices down in Egypt amid uncertain economic outlook, expected dollar price hike
#
#
#
# Gold prices in the Egyptian market saw a fluctuation on Monday amid the uncertainty cast by an expected rise in the US dollar price and inflation caused by the Russian war in Ukraine, as well as rising food and energy prices.

# %%
economy_articles = pd.DataFrame({"article_title": title_economy})
economy_articles['category'] = "economy"
# remove leading and trailin spaces
economy_articles['article_title'] = economy_articles['article_title'].str.strip()

# %%
display(economy_articles.head())
print()
print(economy_articles.shape)
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                 article_title  \
# 0                                                                                                                  Egypt-based Paymob raises $50 mln in Series B funding round \n\n\n\nEgypt-based Paymob, a financial services for merchants platform, raised $50 million in Series B funding, which the platform will use to grow its product range, expanding in the Egyptian market as well as into new markets across the Middle East and Africa region.
# 1                                                                                                  Egypt’s inflation speeds up amid war in Ukraine, rising food and energy prices\n\n\n\nEgypt’s headline annual inflation rate accelerated to 14.9 percent in April, up from the 12.1 percent recorded in March and 4.4 percent in the corresponding month in 2021, the Central Agency for Public Mobilisation and Statistics (CAPMAS) announced on Tuesday.
# 2  EBRD upgrades Egypt’s GDP growth forecasts in FY2021/22 by 0.8%\n\n\n\nThe European Bank for Reconstruction and Development (EBRD) raised its projections for Egypt’s GDP growth for the current FY2021/22 to 5.7 percent — which ends in June — up from the 4.9 percent it projected in November before slowing down to 5 percent in FY2022/23 — which begins in July — according to the Regional Economic Prospects Report the bank released on Tuesday.
# 3                                                                                                                              Gold prices down in Egypt amid uncertain economic outlook, expected dollar price hike\n\n\n\nGold prices in the Egyptian market saw a fluctuation on Monday amid the uncertainty cast by an expected rise in the US dollar price and inflation caused by the Russian war in Ukraine, as well as rising food and energy prices.
# 4                                                                                                                  Egypt, EU ink €138 mln development finance deals covering several sectors\n\n\n\nEgypt and the European Union (EU) delegation in Egypt signed on Monday a number of development finance agreements worth €138 million covering healthcare, administrative reform, the environment, rural and social development, and enhancing governance.
#
#   category
# 0  economy
# 1  economy
# 2  economy
# 3  economy
# 4  economy
# (10000, 2)

# %%
economy_articles.to_csv("economy_2.csv")

# %% [markdown]
# ## Sports

# %%
# %%time
title_sports = []
for i in range(0, 10000, 20):
    response = requests.get("https://english.ahram.org.eg/AllCategory/6/55/Sports/World/"+str(i)+".aspx")
    src = response.content
    soup = BeautifulSoup(src, 'lxml')
    articles_titles = soup.find_all("div", {"class":"col-md-12 col-lg-12 mar-top-outer"})
    # append articles in each page to article_title
    for j in range(len(articles_titles)):
        title_sports.append(articles_titles[j].text)
    print(f"iteration {int(i/20)} is done")
print("DONE !")
# Out:
# iteration 0 is done
# iteration 1 is done
# iteration 2 is done
# iteration 3 is done
# iteration 4 is done
# iteration 5 is done
# iteration 6 is done
# iteration 7 is done
# iteration 8 is done
# iteration 9 is done
# iteration 10 is done
# iteration 11 is done
# iteration 12 is done
# iteration 13 is done
# iteration 14 is done
# iteration 15 is done
# iteration 16 is done
# iteration 17 is done
# iteration 18 is done
# iteration 19 is done
# iteration 20 is done
# iteration 21 is done
# iteration 22 is done
# iteration 23 is done
# iteration 24 is done
# iteration 25 is done
# iteration 26 is done
# iteration 27 is done
# iteration 28 is done
# iteration 29 is done
# iteration 30 is done
# iteration 31 is done
# iteration 32 is done
# iteration 33 is done
# iteration 34 is done
# iteration 35 is done
# iteration 36 is done
# iteration 37 is done
# iteration 38 is done
# iteration 39 is done
# iteration 40 is done
# iteration 41 is done
# iteration 42 is done
# iteration 43 is done
# iteration 44 is done
# iteration 45 is done
# iteration 46 is done
# iteration 47 is done
# iteration 48 is done
# iteration 49 is done
# iteration 50 is done
# iteration 51 is done
# iteration 52 is done
# iteration 53 is done
# iteration 54 is done
# iteration 55 is done
# iteration 56 is done
# iteration 57 is done
# iteration 58 is done
# iteration 59 is done
# iteration 60 is done
# iteration 61 is done
# iteration 62 is done
# iteration 63 is done
# iteration 64 is done
# iteration 65 is done
# iteration 66 is done
# iteration 67 is done
# iteration 68 is done
# iteration 69 is done
# iteration 70 is done
# iteration 71 is done
# iteration 72 is done
# iteration 73 is done
# iteration 74 is done
# iteration 75 is done
# iteration 76 is done
# iteration 77 is done
# iteration 78 is done
# iteration 79 is done
# iteration 80 is done
# iteration 81 is done
# iteration 82 is done
# iteration 83 is done
# iteration 84 is done
# iteration 85 is done
# iteration 86 is done
# iteration 87 is done
# iteration 88 is done
# iteration 89 is done
# iteration 90 is done
# iteration 91 is done
# iteration 92 is done
# iteration 93 is done
# iteration 94 is done
# iteration 95 is done
# iteration 96 is done
# iteration 97 is done
# iteration 98 is done
# iteration 99 is done
# iteration 100 is done
# iteration 101 is done
# iteration 102 is done
# iteration 103 is done
# iteration 104 is done
# iteration 105 is done
# iteration 106 is done
# iteration 107 is done
# iteration 108 is done
# iteration 109 is done
# iteration 110 is done
# iteration 111 is done
# iteration 112 is done
# iteration 113 is done
# iteration 114 is done
# iteration 115 is done
# iteration 116 is done
# iteration 117 is done
# iteration 118 is done
# iteration 119 is done
# iteration 120 is done
# iteration 121 is done
# iteration 122 is done
# iteration 123 is done
# iteration 124 is done
# iteration 125 is done
# iteration 126 is done
# iteration 127 is done
# iteration 128 is done
# iteration 129 is done
# iteration 130 is done
# iteration 131 is done
# iteration 132 is done
# iteration 133 is done
# iteration 134 is done
# iteration 135 is done
# iteration 136 is done
# iteration 137 is done
# iteration 138 is done
# iteration 139 is done
# iteration 140 is done
# iteration 141 is done
# iteration 142 is done
# iteration 143 is done
# iteration 144 is done
# iteration 145 is done
# iteration 146 is done
# iteration 147 is done
# iteration 148 is done
# iteration 149 is done
# iteration 150 is done
# iteration 151 is done
# iteration 152 is done
# iteration 153 is done
# iteration 154 is done
# iteration 155 is done
# iteration 156 is done
# iteration 157 is done
# iteration 158 is done
# iteration 159 is done
# iteration 160 is done
# iteration 161 is done
# iteration 162 is done
# iteration 163 is done
# iteration 164 is done
# iteration 165 is done
# iteration 166 is done
# iteration 167 is done
# iteration 168 is done
# iteration 169 is done
# iteration 170 is done
# iteration 171 is done
# iteration 172 is done
# iteration 173 is done
# iteration 174 is done
# iteration 175 is done
# iteration 176 is done
# iteration 177 is done
# iteration 178 is done
# iteration 179 is done
# iteration 180 is done
# iteration 181 is done
# iteration 182 is done
# iteration 183 is done
# iteration 184 is done
# iteration 185 is done
# iteration 186 is done
# iteration 187 is done
# iteration 188 is done
# iteration 189 is done
# iteration 190 is done
# iteration 191 is done
# iteration 192 is done
# iteration 193 is done
# iteration 194 is done
# iteration 195 is done
# iteration 196 is done
# iteration 197 is done
# iteration 198 is done
# iteration 199 is done
# iteration 200 is done
# iteration 201 is done
# iteration 202 is done
# iteration 203 is done
# iteration 204 is done
# iteration 205 is done
# iteration 206 is done
# iteration 207 is done
# iteration 208 is done
# iteration 209 is done
# iteration 210 is done
# iteration 211 is done
# iteration 212 is done
# iteration 213 is done
# iteration 214 is done
# iteration 215 is done
# iteration 216 is done
# iteration 217 is done
# iteration 218 is done
# iteration 219 is done
# iteration 220 is done
# iteration 221 is done
# iteration 222 is done
# iteration 223 is done
# iteration 224 is done
# iteration 225 is done
# iteration 226 is done
# iteration 227 is done
# iteration 228 is done
# iteration 229 is done
# iteration 230 is done
# iteration 231 is done
# iteration 232 is done
# iteration 233 is done
# iteration 234 is done
# iteration 235 is done
# iteration 236 is done
# iteration 237 is done
# iteration 238 is done
# iteration 239 is done
# iteration 240 is done
# iteration 241 is done
# iteration 242 is done
# iteration 243 is done
# iteration 244 is done
# iteration 245 is done
# iteration 246 is done
# iteration 247 is done
# iteration 248 is done
# iteration 249 is done
# iteration 250 is done
# iteration 251 is done
# iteration 252 is done
# iteration 253 is done
# iteration 254 is done
# iteration 255 is done
# iteration 256 is done
# iteration 257 is done
# iteration 258 is done
# iteration 259 is done
# iteration 260 is done
# iteration 261 is done
# iteration 262 is done
# iteration 263 is done
# iteration 264 is done
# iteration 265 is done
# iteration 266 is done
# iteration 267 is done
# iteration 268 is done
# iteration 269 is done
# iteration 270 is done
# iteration 271 is done
# iteration 272 is done
# iteration 273 is done
# iteration 274 is done
# iteration 275 is done
# iteration 276 is done
# iteration 277 is done
# iteration 278 is done
# iteration 279 is done
# iteration 280 is done
# iteration 281 is done
# iteration 282 is done
# iteration 283 is done
# iteration 284 is done
# iteration 285 is done
# iteration 286 is done
# iteration 287 is done
# iteration 288 is done
# iteration 289 is done
# iteration 290 is done
# iteration 291 is done
# iteration 292 is done
# iteration 293 is done
# iteration 294 is done
# iteration 295 is done
# iteration 296 is done
# iteration 297 is done
# iteration 298 is done
# iteration 299 is done
# iteration 300 is done
# iteration 301 is done
# iteration 302 is done
# iteration 303 is done
# iteration 304 is done
# iteration 305 is done
# iteration 306 is done
# iteration 307 is done
# iteration 308 is done
# iteration 309 is done
# iteration 310 is done
# iteration 311 is done
# iteration 312 is done
# iteration 313 is done
# iteration 314 is done
# iteration 315 is done
# iteration 316 is done
# iteration 317 is done
# iteration 318 is done
# iteration 319 is done
# iteration 320 is done
# iteration 321 is done
# iteration 322 is done
# iteration 323 is done
# iteration 324 is done
# iteration 325 is done
# iteration 326 is done
# iteration 327 is done
# iteration 328 is done
# iteration 329 is done
# iteration 330 is done
# iteration 331 is done
# iteration 332 is done
# iteration 333 is done
# iteration 334 is done
# iteration 335 is done
# iteration 336 is done
# iteration 337 is done
# iteration 338 is done
# iteration 339 is done
# iteration 340 is done
# iteration 341 is done
# iteration 342 is done
# iteration 343 is done
# iteration 344 is done
# iteration 345 is done
# iteration 346 is done
# iteration 347 is done
# iteration 348 is done
# iteration 349 is done
# iteration 350 is done
# iteration 351 is done
# iteration 352 is done
# iteration 353 is done
# iteration 354 is done
# iteration 355 is done
# iteration 356 is done
# iteration 357 is done
# iteration 358 is done
# iteration 359 is done
# iteration 360 is done
# iteration 361 is done
# iteration 362 is done
# iteration 363 is done
# iteration 364 is done
# iteration 365 is done
# iteration 366 is done
# iteration 367 is done
# iteration 368 is done
# iteration 369 is done
# iteration 370 is done
# iteration 371 is done
# iteration 372 is done
# iteration 373 is done
# iteration 374 is done
# iteration 375 is done
# iteration 376 is done
# iteration 377 is done
# iteration 378 is done
# iteration 379 is done
# iteration 380 is done
# iteration 381 is done
# iteration 382 is done
# iteration 383 is done
# iteration 384 is done
# iteration 385 is done
# iteration 386 is done
# iteration 387 is done
# iteration 388 is done
# iteration 389 is done
# iteration 390 is done
# iteration 391 is done
# iteration 392 is done
# iteration 393 is done
# iteration 394 is done
# iteration 395 is done
# iteration 396 is done
# iteration 397 is done
# iteration 398 is done
# iteration 399 is done
# iteration 400 is done
# iteration 401 is done
# iteration 402 is done
# iteration 403 is done
# iteration 404 is done
# iteration 405 is done
# iteration 406 is done
# iteration 407 is done
# iteration 408 is done
# iteration 409 is done
# iteration 410 is done
# iteration 411 is done
# iteration 412 is done
# iteration 413 is done
# iteration 414 is done
# iteration 415 is done
# iteration 416 is done
# iteration 417 is done
# iteration 418 is done
# iteration 419 is done
# iteration 420 is done
# iteration 421 is done
# iteration 422 is done
# iteration 423 is done
# iteration 424 is done
# iteration 425 is done
# iteration 426 is done
# iteration 427 is done
# iteration 428 is done
# iteration 429 is done
# iteration 430 is done
# iteration 431 is done
# iteration 432 is done
# iteration 433 is done
# iteration 434 is done
# iteration 435 is done
# iteration 436 is done
# iteration 437 is done
# iteration 438 is done
# iteration 439 is done
# iteration 440 is done
# iteration 441 is done
# iteration 442 is done
# iteration 443 is done
# iteration 444 is done
# iteration 445 is done
# iteration 446 is done
# iteration 447 is done
# iteration 448 is done
# iteration 449 is done
# iteration 450 is done
# iteration 451 is done
# iteration 452 is done
# iteration 453 is done
# iteration 454 is done
# iteration 455 is done
# iteration 456 is done
# iteration 457 is done
# iteration 458 is done
# iteration 459 is done
# iteration 460 is done
# iteration 461 is done
# iteration 462 is done
# iteration 463 is done
# iteration 464 is done
# iteration 465 is done
# iteration 466 is done
# iteration 467 is done
# iteration 468 is done
# iteration 469 is done
# iteration 470 is done
# iteration 471 is done
# iteration 472 is done
# iteration 473 is done
# iteration 474 is done
# iteration 475 is done
# iteration 476 is done
# iteration 477 is done
# iteration 478 is done
# iteration 479 is done
# iteration 480 is done
# iteration 481 is done
# iteration 482 is done
# iteration 483 is done
# iteration 484 is done
# iteration 485 is done
# iteration 486 is done
# iteration 487 is done
# iteration 488 is done
# iteration 489 is done
# iteration 490 is done
# iteration 491 is done
# iteration 492 is done
# iteration 493 is done
# iteration 494 is done
# iteration 495 is done
# iteration 496 is done
# iteration 497 is done
# iteration 498 is done
# iteration 499 is done
# DONE !
# CPU times: total: 20.5 s
# Wall time: 15min 52s

# %%
# testing
print(title_sports[2])
# Out:
# Spain La Liga results & fixtures (37th matchday)
#
#
#
# Follow Ahram Online's coverage of Spain La Liga matches of the 2021/2022 season (14 / 15 May)

# %%
sports_articles = pd.DataFrame({"article_title": title_sports})
sports_articles['category'] = "sports"
# remove leading and trailin spaces
sports_articles['article_title'] = sports_articles['article_title'].str.strip()

# %%
display(sports_articles.head())
print()
print(sports_articles.shape)
# Out:
#                                                                                                                                                                                                                                                                    article_title  \
# 0                                        Barcelona financial situation could dictate De Jong future, says Xavi\n\n\n\nBarcelona coach Xavi Hernandez suggested on Saturday the club’s dire financial situation could force them to consider selling Frenkie de Jong this summer.
# 1                Liverpool win FA Cup final in shoot-out against Chelsea\n\n\n\nLiverpool held their nerve to win the FA Cup for the first time since 2006 after a dramatic penalty shoot-out against Chelsea as the quadruple chasers kept their history bid alive on Saturday.
# 2                                                                                                                          Spain La Liga results & fixtures (37th matchday)\n\n\n\nFollow Ahram Online's coverage of Spain La Liga matches of the 2021/2022 season (14 / 15 May)
# 3                               Last-gasp Stuttgart survives in dramatic Bundesliga finale\n\n\n\nWataru Endo scored in injury time for Stuttgart to clinch Bundesliga survival at Hertha Berlin's expense after a dramatic 2-1 win over Cologne in the final round on Saturday.
# 4  Salernitana rescues 1-1 draw at Empoli, Venezia relegated\n\n\n\nDiego Perotti was in tears at the final whistle and had to be consoled by his teammates after his late penalty was saved in relegation-threatened Salernitana's 1-1 draw with Empoli in Serie A on Saturday.
#
#   category
# 0   sports
# 1   sports
# 2   sports
# 3   sports
# 4   sports
# (10000, 2)

# %%
sports_articles.to_csv("sports_2.csv")

# %% [markdown]
# economy and sports data (10000, 9880) are close in terms of number of records, but art data (1775) is too small in comparison.
#
# We'll need to collect more data from different categories of art.

# %% [markdown]
# ## Arts

# %% [markdown]
# ### VisualArt

# %%
# %%time
title_arts = []
for i in range(0, 10000, 20):
    response = requests.get("https://english.ahram.org.eg/AllCategory/5/25/Arts%20&%20Culture/Visual%20Art/"+str(i)+".aspx")
    src = response.content
    soup = BeautifulSoup(src, 'lxml')
    articles_titles = soup.find_all("div", {"class":"col-md-12 col-lg-12 mar-top-outer"})
    # append articles in each page to article_title
    for j in range(len(articles_titles)):
        title_arts.append(articles_titles[j].text)
    print(f"iteration {int(i/20)} is done")
print("DONE !")
# Out:
# iteration 0 is done
# iteration 1 is done
# iteration 2 is done
# iteration 3 is done
# iteration 4 is done
# iteration 5 is done
# iteration 6 is done
# iteration 7 is done
# iteration 8 is done
# iteration 9 is done
# iteration 10 is done
# iteration 11 is done
# iteration 12 is done
# iteration 13 is done
# iteration 14 is done
# iteration 15 is done
# iteration 16 is done
# iteration 17 is done
# iteration 18 is done
# iteration 19 is done
# iteration 20 is done
# iteration 21 is done
# iteration 22 is done
# iteration 23 is done
# iteration 24 is done
# iteration 25 is done
# iteration 26 is done
# iteration 27 is done
# iteration 28 is done
# iteration 29 is done
# iteration 30 is done
# iteration 31 is done
# iteration 32 is done
# iteration 33 is done
# iteration 34 is done
# iteration 35 is done
# iteration 36 is done
# iteration 37 is done
# iteration 38 is done
# iteration 39 is done
# iteration 40 is done
# iteration 41 is done
# iteration 42 is done
# iteration 43 is done
# iteration 44 is done
# iteration 45 is done
# iteration 46 is done
# iteration 47 is done
# iteration 48 is done
# iteration 49 is done
# iteration 50 is done
# iteration 51 is done
# iteration 52 is done
# iteration 53 is done
# iteration 54 is done
# iteration 55 is done
# iteration 56 is done
# iteration 57 is done
# iteration 58 is done
# iteration 59 is done
# iteration 60 is done
# iteration 61 is done
# iteration 62 is done
# iteration 63 is done
# iteration 64 is done
# iteration 65 is done
# iteration 66 is done
# iteration 67 is done
# iteration 68 is done
# iteration 69 is done
# iteration 70 is done
# iteration 71 is done
# iteration 72 is done
# iteration 73 is done
# iteration 74 is done
# iteration 75 is done
# iteration 76 is done
# iteration 77 is done
# iteration 78 is done
# iteration 79 is done
# iteration 80 is done
# iteration 81 is done
# iteration 82 is done
# iteration 83 is done
# iteration 84 is done
# iteration 85 is done
# iteration 86 is done
# iteration 87 is done
# iteration 88 is done
# iteration 89 is done
# iteration 90 is done
# iteration 91 is done
# iteration 92 is done
# iteration 93 is done
# iteration 94 is done
# iteration 95 is done
# iteration 96 is done
# iteration 97 is done
# iteration 98 is done
# iteration 99 is done
# iteration 100 is done
# iteration 101 is done
# iteration 102 is done
# iteration 103 is done
# iteration 104 is done
# iteration 105 is done
# iteration 106 is done
# iteration 107 is done
# iteration 108 is done
# iteration 109 is done
# iteration 110 is done
# iteration 111 is done
# iteration 112 is done
# iteration 113 is done
# iteration 114 is done
# iteration 115 is done
# iteration 116 is done
# iteration 117 is done
# iteration 118 is done
# iteration 119 is done
# iteration 120 is done
# iteration 121 is done
# iteration 122 is done
# iteration 123 is done
# iteration 124 is done
# iteration 125 is done
# iteration 126 is done
# iteration 127 is done
# iteration 128 is done
# iteration 129 is done
# iteration 130 is done
# iteration 131 is done
# iteration 132 is done
# iteration 133 is done
# iteration 134 is done
# iteration 135 is done
# iteration 136 is done
# iteration 137 is done
# iteration 138 is done
# iteration 139 is done
# iteration 140 is done
# iteration 141 is done
# iteration 142 is done
# iteration 143 is done
# iteration 144 is done
# iteration 145 is done
# iteration 146 is done
# iteration 147 is done
# iteration 148 is done
# iteration 149 is done
# iteration 150 is done
# iteration 151 is done
# iteration 152 is done
# iteration 153 is done
# iteration 154 is done
# iteration 155 is done
# iteration 156 is done
# iteration 157 is done
# iteration 158 is done
# iteration 159 is done
# iteration 160 is done
# iteration 161 is done
# iteration 162 is done
# iteration 163 is done
# iteration 164 is done
# iteration 165 is done
# iteration 166 is done
# iteration 167 is done
# iteration 168 is done
# iteration 169 is done
# iteration 170 is done
# iteration 171 is done
# iteration 172 is done
# iteration 173 is done
# iteration 174 is done
# iteration 175 is done
# iteration 176 is done
# iteration 177 is done
# iteration 178 is done
# iteration 179 is done
# iteration 180 is done
# iteration 181 is done
# iteration 182 is done
# iteration 183 is done
# iteration 184 is done
# iteration 185 is done
# iteration 186 is done
# iteration 187 is done
# iteration 188 is done
# iteration 189 is done
# iteration 190 is done
# iteration 191 is done
# iteration 192 is done
# iteration 193 is done
# iteration 194 is done
# iteration 195 is done
# iteration 196 is done
# iteration 197 is done
# iteration 198 is done
# iteration 199 is done
# iteration 200 is done
# iteration 201 is done
# iteration 202 is done
# iteration 203 is done
# iteration 204 is done
# iteration 205 is done
# iteration 206 is done
# iteration 207 is done
# iteration 208 is done
# iteration 209 is done
# iteration 210 is done
# iteration 211 is done
# iteration 212 is done
# iteration 213 is done
# iteration 214 is done
# iteration 215 is done
# iteration 216 is done
# iteration 217 is done
# iteration 218 is done
# iteration 219 is done
# iteration 220 is done
# iteration 221 is done
# iteration 222 is done
# iteration 223 is done
# iteration 224 is done
# iteration 225 is done
# iteration 226 is done
# iteration 227 is done
# iteration 228 is done
# iteration 229 is done
# iteration 230 is done
# iteration 231 is done
# iteration 232 is done
# iteration 233 is done
# iteration 234 is done
# iteration 235 is done
# iteration 236 is done
# iteration 237 is done
# iteration 238 is done
# iteration 239 is done
# iteration 240 is done
# iteration 241 is done
# iteration 242 is done
# iteration 243 is done
# iteration 244 is done
# iteration 245 is done
# iteration 246 is done
# iteration 247 is done
# iteration 248 is done
# iteration 249 is done
# iteration 250 is done
# iteration 251 is done
# iteration 252 is done
# iteration 253 is done
# iteration 254 is done
# iteration 255 is done
# iteration 256 is done
# iteration 257 is done
# iteration 258 is done
# iteration 259 is done
# iteration 260 is done
# iteration 261 is done
# iteration 262 is done
# iteration 263 is done
# iteration 264 is done
# iteration 265 is done
# iteration 266 is done
# iteration 267 is done
# iteration 268 is done
# iteration 269 is done
# iteration 270 is done
# iteration 271 is done
# iteration 272 is done
# iteration 273 is done
# iteration 274 is done
# iteration 275 is done
# iteration 276 is done
# iteration 277 is done
# iteration 278 is done
# iteration 279 is done
# iteration 280 is done
# iteration 281 is done
# iteration 282 is done
# iteration 283 is done
# iteration 284 is done
# iteration 285 is done
# iteration 286 is done
# iteration 287 is done
# iteration 288 is done
# iteration 289 is done
# iteration 290 is done
# iteration 291 is done
# iteration 292 is done
# iteration 293 is done
# iteration 294 is done
# iteration 295 is done
# iteration 296 is done
# iteration 297 is done
# iteration 298 is done
# iteration 299 is done
# iteration 300 is done
# iteration 301 is done
# iteration 302 is done
# iteration 303 is done
# iteration 304 is done
# iteration 305 is done
# iteration 306 is done
# iteration 307 is done
# iteration 308 is done
# iteration 309 is done
# iteration 310 is done
# iteration 311 is done
# iteration 312 is done
# iteration 313 is done
# iteration 314 is done
# iteration 315 is done
# iteration 316 is done
# iteration 317 is done
# iteration 318 is done
# iteration 319 is done
# iteration 320 is done
# iteration 321 is done
# iteration 322 is done
# iteration 323 is done
# iteration 324 is done
# iteration 325 is done
# iteration 326 is done
# iteration 327 is done
# iteration 328 is done
# iteration 329 is done
# iteration 330 is done
# iteration 331 is done
# iteration 332 is done
# iteration 333 is done
# iteration 334 is done
# iteration 335 is done
# iteration 336 is done
# iteration 337 is done
# iteration 338 is done
# iteration 339 is done
# iteration 340 is done
# iteration 341 is done
# iteration 342 is done
# iteration 343 is done
# iteration 344 is done
# iteration 345 is done
# iteration 346 is done
# iteration 347 is done
# iteration 348 is done
# iteration 349 is done
# iteration 350 is done
# iteration 351 is done
# iteration 352 is done
# iteration 353 is done
# iteration 354 is done
# iteration 355 is done
# iteration 356 is done
# iteration 357 is done
# iteration 358 is done
# iteration 359 is done
# iteration 360 is done
# iteration 361 is done
# iteration 362 is done
# iteration 363 is done
# iteration 364 is done
# iteration 365 is done
# iteration 366 is done
# iteration 367 is done
# iteration 368 is done
# iteration 369 is done
# iteration 370 is done
# iteration 371 is done
# iteration 372 is done
# iteration 373 is done
# iteration 374 is done
# iteration 375 is done
# iteration 376 is done
# iteration 377 is done
# iteration 378 is done
# iteration 379 is done
# iteration 380 is done
# iteration 381 is done
# iteration 382 is done
# iteration 383 is done
# iteration 384 is done
# iteration 385 is done
# iteration 386 is done
# iteration 387 is done
# iteration 388 is done
# iteration 389 is done
# iteration 390 is done
# iteration 391 is done
# iteration 392 is done
# iteration 393 is done
# iteration 394 is done
# iteration 395 is done
# iteration 396 is done
# iteration 397 is done
# iteration 398 is done
# iteration 399 is done
# iteration 400 is done
# iteration 401 is done
# iteration 402 is done
# iteration 403 is done
# iteration 404 is done
# iteration 405 is done
# iteration 406 is done
# iteration 407 is done
# iteration 408 is done
# iteration 409 is done
# iteration 410 is done
# iteration 411 is done
# iteration 412 is done
# iteration 413 is done
# iteration 414 is done
# iteration 415 is done
# iteration 416 is done
# iteration 417 is done
# iteration 418 is done
# iteration 419 is done
# iteration 420 is done
# iteration 421 is done
# iteration 422 is done
# iteration 423 is done
# iteration 424 is done
# iteration 425 is done
# iteration 426 is done
# iteration 427 is done
# iteration 428 is done
# iteration 429 is done
# iteration 430 is done
# iteration 431 is done
# iteration 432 is done
# iteration 433 is done
# iteration 434 is done
# iteration 435 is done
# iteration 436 is done
# iteration 437 is done
# iteration 438 is done
# iteration 439 is done
# iteration 440 is done
# iteration 441 is done
# iteration 442 is done
# iteration 443 is done
# iteration 444 is done
# iteration 445 is done
# iteration 446 is done
# iteration 447 is done
# iteration 448 is done
# iteration 449 is done
# iteration 450 is done
# iteration 451 is done
# iteration 452 is done
# iteration 453 is done
# iteration 454 is done
# iteration 455 is done
# iteration 456 is done
# iteration 457 is done
# iteration 458 is done
# iteration 459 is done
# iteration 460 is done
# iteration 461 is done
# iteration 462 is done
# iteration 463 is done
# iteration 464 is done
# iteration 465 is done
# iteration 466 is done
# iteration 467 is done
# iteration 468 is done
# iteration 469 is done
# iteration 470 is done
# iteration 471 is done
# iteration 472 is done
# iteration 473 is done
# iteration 474 is done
# iteration 475 is done
# iteration 476 is done
# iteration 477 is done
# iteration 478 is done
# iteration 479 is done
# iteration 480 is done
# iteration 481 is done
# iteration 482 is done
# iteration 483 is done
# iteration 484 is done
# iteration 485 is done
# iteration 486 is done
# iteration 487 is done
# iteration 488 is done
# iteration 489 is done
# iteration 490 is done
# iteration 491 is done
# iteration 492 is done
# iteration 493 is done
# iteration 494 is done
# iteration 495 is done
# iteration 496 is done
# iteration 497 is done
# iteration 498 is done
# iteration 499 is done
# DONE !
# CPU times: total: 55.4 s
# Wall time: 16min 29s

# %% [markdown]
# ### Film

# %%
# %%time
for i in range(0, 10000, 20):
    response = requests.get("https://english.ahram.org.eg/AllCategory/5/32/Arts%20&%20Culture/Film/"+str(i)+".aspx")
    src = response.content
    soup = BeautifulSoup(src, 'lxml')
    articles_titles = soup.find_all("div", {"class":"col-md-12 col-lg-12 mar-top-outer"})
    # append articles in each page to article_title
    for j in range(len(articles_titles)):
        title_arts.append(articles_titles[j].text)
    print(f"iteration {int(i/20)} is done")
print("DONE !")
# Out:
# iteration 0 is done
# iteration 1 is done
# iteration 2 is done
# iteration 3 is done
# iteration 4 is done
# iteration 5 is done
# iteration 6 is done
# iteration 7 is done
# iteration 8 is done
# iteration 9 is done
# iteration 10 is done
# iteration 11 is done
# iteration 12 is done
# iteration 13 is done
# iteration 14 is done
# iteration 15 is done
# iteration 16 is done
# iteration 17 is done
# iteration 18 is done
# iteration 19 is done
# iteration 20 is done
# iteration 21 is done
# iteration 22 is done
# iteration 23 is done
# iteration 24 is done
# iteration 25 is done
# iteration 26 is done
# iteration 27 is done
# iteration 28 is done
# iteration 29 is done
# iteration 30 is done
# iteration 31 is done
# iteration 32 is done
# iteration 33 is done
# iteration 34 is done
# iteration 35 is done
# iteration 36 is done
# iteration 37 is done
# iteration 38 is done
# iteration 39 is done
# iteration 40 is done
# iteration 41 is done
# iteration 42 is done
# iteration 43 is done
# iteration 44 is done
# iteration 45 is done
# iteration 46 is done
# iteration 47 is done
# iteration 48 is done
# iteration 49 is done
# iteration 50 is done
# iteration 51 is done
# iteration 52 is done
# iteration 53 is done
# iteration 54 is done
# iteration 55 is done
# iteration 56 is done
# iteration 57 is done
# iteration 58 is done
# iteration 59 is done
# iteration 60 is done
# iteration 61 is done
# iteration 62 is done
# iteration 63 is done
# iteration 64 is done
# iteration 65 is done
# iteration 66 is done
# iteration 67 is done
# iteration 68 is done
# iteration 69 is done
# iteration 70 is done
# iteration 71 is done
# iteration 72 is done
# iteration 73 is done
# iteration 74 is done
# iteration 75 is done
# iteration 76 is done
# iteration 77 is done
# iteration 78 is done
# iteration 79 is done
# iteration 80 is done
# iteration 81 is done
# iteration 82 is done
# iteration 83 is done
# iteration 84 is done
# iteration 85 is done
# iteration 86 is done
# iteration 87 is done
# iteration 88 is done
# iteration 89 is done
# iteration 90 is done
# iteration 91 is done
# iteration 92 is done
# iteration 93 is done
# iteration 94 is done
# iteration 95 is done
# iteration 96 is done
# iteration 97 is done
# iteration 98 is done
# iteration 99 is done
# iteration 100 is done
# iteration 101 is done
# iteration 102 is done
# iteration 103 is done
# iteration 104 is done
# iteration 105 is done
# iteration 106 is done
# iteration 107 is done
# iteration 108 is done
# iteration 109 is done
# iteration 110 is done
# iteration 111 is done
# iteration 112 is done
# iteration 113 is done
# iteration 114 is done
# iteration 115 is done
# iteration 116 is done
# iteration 117 is done
# iteration 118 is done
# iteration 119 is done
# iteration 120 is done
# iteration 121 is done
# iteration 122 is done
# iteration 123 is done
# iteration 124 is done
# iteration 125 is done
# iteration 126 is done
# iteration 127 is done
# iteration 128 is done
# iteration 129 is done
# iteration 130 is done
# iteration 131 is done
# iteration 132 is done
# iteration 133 is done
# iteration 134 is done
# iteration 135 is done
# iteration 136 is done
# iteration 137 is done
# iteration 138 is done
# iteration 139 is done
# iteration 140 is done
# iteration 141 is done
# iteration 142 is done
# iteration 143 is done
# iteration 144 is done
# iteration 145 is done
# iteration 146 is done
# iteration 147 is done
# iteration 148 is done
# iteration 149 is done
# iteration 150 is done
# iteration 151 is done
# iteration 152 is done
# iteration 153 is done
# iteration 154 is done
# iteration 155 is done
# iteration 156 is done
# iteration 157 is done
# iteration 158 is done
# iteration 159 is done
# iteration 160 is done
# iteration 161 is done
# iteration 162 is done
# iteration 163 is done
# iteration 164 is done
# iteration 165 is done
# iteration 166 is done
# iteration 167 is done
# iteration 168 is done
# iteration 169 is done
# iteration 170 is done
# iteration 171 is done
# iteration 172 is done
# iteration 173 is done
# iteration 174 is done
# iteration 175 is done
# iteration 176 is done
# iteration 177 is done
# iteration 178 is done
# iteration 179 is done
# iteration 180 is done
# iteration 181 is done
# iteration 182 is done
# iteration 183 is done
# iteration 184 is done
# iteration 185 is done
# iteration 186 is done
# iteration 187 is done
# iteration 188 is done
# iteration 189 is done
# iteration 190 is done
# iteration 191 is done
# iteration 192 is done
# iteration 193 is done
# iteration 194 is done
# iteration 195 is done
# iteration 196 is done
# iteration 197 is done
# iteration 198 is done
# iteration 199 is done
# iteration 200 is done
# iteration 201 is done
# iteration 202 is done
# iteration 203 is done
# iteration 204 is done
# iteration 205 is done
# iteration 206 is done
# iteration 207 is done
# iteration 208 is done
# iteration 209 is done
# iteration 210 is done
# iteration 211 is done
# iteration 212 is done
# iteration 213 is done
# iteration 214 is done
# iteration 215 is done
# iteration 216 is done
# iteration 217 is done
# iteration 218 is done
# iteration 219 is done
# iteration 220 is done
# iteration 221 is done
# iteration 222 is done
# iteration 223 is done
# iteration 224 is done
# iteration 225 is done
# iteration 226 is done
# iteration 227 is done
# iteration 228 is done
# iteration 229 is done
# iteration 230 is done
# iteration 231 is done
# iteration 232 is done
# iteration 233 is done
# iteration 234 is done
# iteration 235 is done
# iteration 236 is done
# iteration 237 is done
# iteration 238 is done
# iteration 239 is done
# iteration 240 is done
# iteration 241 is done
# iteration 242 is done
# iteration 243 is done
# iteration 244 is done
# iteration 245 is done
# iteration 246 is done
# iteration 247 is done
# iteration 248 is done
# iteration 249 is done
# iteration 250 is done
# iteration 251 is done
# iteration 252 is done
# iteration 253 is done
# iteration 254 is done
# iteration 255 is done
# iteration 256 is done
# iteration 257 is done
# iteration 258 is done
# iteration 259 is done
# iteration 260 is done
# iteration 261 is done
# iteration 262 is done
# iteration 263 is done
# iteration 264 is done
# iteration 265 is done
# iteration 266 is done
# iteration 267 is done
# iteration 268 is done
# iteration 269 is done
# iteration 270 is done
# iteration 271 is done
# iteration 272 is done
# iteration 273 is done
# iteration 274 is done
# iteration 275 is done
# iteration 276 is done
# iteration 277 is done
# iteration 278 is done
# iteration 279 is done
# iteration 280 is done
# iteration 281 is done
# iteration 282 is done
# iteration 283 is done
# iteration 284 is done
# iteration 285 is done
# iteration 286 is done
# iteration 287 is done
# iteration 288 is done
# iteration 289 is done
# iteration 290 is done
# iteration 291 is done
# iteration 292 is done
# iteration 293 is done
# iteration 294 is done
# iteration 295 is done
# iteration 296 is done
# iteration 297 is done
# iteration 298 is done
# iteration 299 is done
# iteration 300 is done
# iteration 301 is done
# iteration 302 is done
# iteration 303 is done
# iteration 304 is done
# iteration 305 is done
# iteration 306 is done
# iteration 307 is done
# iteration 308 is done
# iteration 309 is done
# iteration 310 is done
# iteration 311 is done
# iteration 312 is done
# iteration 313 is done
# iteration 314 is done
# iteration 315 is done
# iteration 316 is done
# iteration 317 is done
# iteration 318 is done
# iteration 319 is done
# iteration 320 is done
# iteration 321 is done
# iteration 322 is done
# iteration 323 is done
# iteration 324 is done
# iteration 325 is done
# iteration 326 is done
# iteration 327 is done
# iteration 328 is done
# iteration 329 is done
# iteration 330 is done
# iteration 331 is done
# iteration 332 is done
# iteration 333 is done
# iteration 334 is done
# iteration 335 is done
# iteration 336 is done
# iteration 337 is done
# iteration 338 is done
# iteration 339 is done
# iteration 340 is done
# iteration 341 is done
# iteration 342 is done
# iteration 343 is done
# iteration 344 is done
# iteration 345 is done
# iteration 346 is done
# iteration 347 is done
# iteration 348 is done
# iteration 349 is done
# iteration 350 is done
# iteration 351 is done
# iteration 352 is done
# iteration 353 is done
# iteration 354 is done
# iteration 355 is done
# iteration 356 is done
# iteration 357 is done
# iteration 358 is done
# iteration 359 is done
# iteration 360 is done
# iteration 361 is done
# iteration 362 is done
# iteration 363 is done
# iteration 364 is done
# iteration 365 is done
# iteration 366 is done
# iteration 367 is done
# iteration 368 is done
# iteration 369 is done
# iteration 370 is done
# iteration 371 is done
# iteration 372 is done
# iteration 373 is done
# iteration 374 is done
# iteration 375 is done
# iteration 376 is done
# iteration 377 is done
# iteration 378 is done
# iteration 379 is done
# iteration 380 is done
# iteration 381 is done
# iteration 382 is done
# iteration 383 is done
# iteration 384 is done
# iteration 385 is done
# iteration 386 is done
# iteration 387 is done
# iteration 388 is done
# iteration 389 is done
# iteration 390 is done
# iteration 391 is done
# iteration 392 is done
# iteration 393 is done
# iteration 394 is done
# iteration 395 is done
# iteration 396 is done
# iteration 397 is done
# iteration 398 is done
# iteration 399 is done
# iteration 400 is done
# iteration 401 is done
# iteration 402 is done
# iteration 403 is done
# iteration 404 is done
# iteration 405 is done
# iteration 406 is done
# iteration 407 is done
# iteration 408 is done
# iteration 409 is done
# iteration 410 is done
# iteration 411 is done
# iteration 412 is done
# iteration 413 is done
# iteration 414 is done
# iteration 415 is done
# iteration 416 is done
# iteration 417 is done
# iteration 418 is done
# iteration 419 is done
# iteration 420 is done
# iteration 421 is done
# iteration 422 is done
# iteration 423 is done
# iteration 424 is done
# iteration 425 is done
# iteration 426 is done
# iteration 427 is done
# iteration 428 is done
# iteration 429 is done
# iteration 430 is done
# iteration 431 is done
# iteration 432 is done
# iteration 433 is done
# iteration 434 is done
# iteration 435 is done
# iteration 436 is done
# iteration 437 is done
# iteration 438 is done
# iteration 439 is done
# iteration 440 is done
# iteration 441 is done
# iteration 442 is done
# iteration 443 is done
# iteration 444 is done
# iteration 445 is done
# iteration 446 is done
# iteration 447 is done
# iteration 448 is done
# iteration 449 is done
# iteration 450 is done
# iteration 451 is done
# iteration 452 is done
# iteration 453 is done
# iteration 454 is done
# iteration 455 is done
# iteration 456 is done
# iteration 457 is done
# iteration 458 is done
# iteration 459 is done
# iteration 460 is done
# iteration 461 is done
# iteration 462 is done
# iteration 463 is done
# iteration 464 is done
# iteration 465 is done
# iteration 466 is done
# iteration 467 is done
# iteration 468 is done
# iteration 469 is done
# iteration 470 is done
# iteration 471 is done
# iteration 472 is done
# iteration 473 is done
# iteration 474 is done
# iteration 475 is done
# iteration 476 is done
# iteration 477 is done
# iteration 478 is done
# iteration 479 is done
# iteration 480 is done

# %%
print(len(title_arts))

# %% [markdown]
# ### Music

# %%
# %%time
for i in range(0, 10000, 20):
    response = requests.get("https://english.ahram.org.eg/AllCategory/5/33/Arts%20&%20Culture/Music/"+str(i)+".aspx")
    src = response.content
    soup = BeautifulSoup(src, 'lxml')
    articles_titles = soup.find_all("div", {"class":"col-md-12 col-lg-12 mar-top-outer"})
    # append articles in each page to article_title
    for j in range(len(articles_titles)):
        title_arts.append(articles_titles[j].text)
    print(f"iteration {int(i/20)} is done")
print("DONE !")

# %% [markdown]
# ### Stage&Street

# %%
# %%time
for i in range(0, 10000, 20):
    response = requests.get("https://english.ahram.org.eg/AllCategory/5/35/Arts%20&%20Culture/Stage%20&%20Street/"+str(i)+".aspx")
    src = response.content
    soup = BeautifulSoup(src, 'lxml')
    articles_titles = soup.find_all("div", {"class":"col-md-12 col-lg-12 mar-top-outer"})
    # append articles in each page to article_title
    for j in range(len(articles_titles)):
        title_arts.append(articles_titles[j].text)
    print(f"iteration {int(i/20)} is done")
print("DONE !")

# %%
# testing
print(title_arts[2])

# %%
art_articles = pd.DataFrame({"article_title": title_arts})
art_articles['category'] = "art"
# remove leading and trailin spaces
art_articles['article_title'] = art_articles['article_title'].str.strip()

# %%
display(art_articles.head(1))
print()
display(art_articles.tail(1))
print(art_articles.shape)

# %%
art_articles.to_csv("arts_2.csv")
